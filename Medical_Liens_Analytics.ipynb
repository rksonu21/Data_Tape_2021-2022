# %%
#Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read csv
df = pd.read_csv('777 Data Tape 2021-2022 (F4D).xlsx - Sheet1.csv', low_memory = False)
df = df.drop(df.index[0]).reset_index(drop=True)

# %%
df.columns = df.iloc[0]
df.reset_index()
# Out:
# 0        index  check    UNIQUE_ID  Plaintiff Last Name  Plaintiff First Name  \
# 0            0  check    UNIQUE_ID  Plaintiff Last Name  Plaintiff First Name
# 1            1      1      F4D-1-1         Abdul-Razzaq                 Nawar
# 2            2      1      F4D-1-2        Abdur-Rasheed                Tracey
# 3            3      1      F4D-1-3        Abdur-Rasheed                Tracey
# 4            4      1      F4D-1-4              Abraham                 Amber
# ...        ...    ...          ...                  ...                   ...
# 196322  196322      1  F4D-396-104        Weller Parker               Suzutte
# 196323  196323      1  F4D-396-105             Williams                Sandra
# 196324  196324      1  F4D-396-106          Yepez Neira                 Julio
# 196325  196325      1  F4D-396-107          Yepez Neira                 Julio
# 196326  196326    NaN          NaN                  NaN                   NaN
#
# ...

# %%
df = df.drop(df.index[0]).reset_index(drop=True)
df.head(20)
# Out:
# 0  check UNIQUE_ID Plaintiff Last Name Plaintiff First Name Portfolio Id  \
# 0      1   F4D-1-1        Abdul-Razzaq                Nawar      NCIP001
# 1      1   F4D-1-2       Abdur-Rasheed               Tracey      NCIP001
# 2      1   F4D-1-3       Abdur-Rasheed               Tracey      NCIP001
# 3      1   F4D-1-4             Abraham                Amber      NCIP001
# 4      1   F4D-1-5              Alatri                Saleh      NCIP001
# 5      1   F4D-1-6              Alatri                Saleh      NCIP001
# 6      1   F4D-1-7            Alghalam                 Jabr      NCIP001
# 7      1   F4D-1-8               Allen              Sparkle      NCIP001
# 8      1   F4D-1-9           Alriyashi                 Wafi      NCIP001
# 9      1  F4D-1-10              Antwan              Jameela      NCIP001
# 10     1  F4D-1-11            Ataallah               Muataz      NCIP001
# 11     1  F4D-1-12              Bailey                Jalen      NCIP001
# ...

# %%
df.describe()
# Out:
# 0        check UNIQUE_ID Plaintiff Last Name Plaintiff First Name  \
# count   196325    196325              196325               196311
# unique       2    196325               10383                 8747
# top          1   F4D-1-1            Williams                Maria
# freq    174459         1                2080                 4474
#
# 0      Portfolio Id                                    Portfolio  \
# count        174911                                       196325
# unique         2746                                         1307
# top        IWMGP003  Injured Workers Medical Group Portfolio #P1
# freq          12507                                        21414
#
# 0      Purchase Date Billing Amount Total Capital Advanced $_Collection  \
# count         196325         196326                 196326       196326
# unique            87           6712                   6969        11092
# top        1/12/2021      $2,101.17                $777.43        $0.00
# ...

# %% [markdown]
# <b>It can be seen upon visual inspection that there exist columns that will not have any tangible contribution to the analytics process that we are about to perform. In order to optimise the execution of our algorithms and avoid wasing of memory resources, we would be better-off dropping these columns.</b>

# %%
columns_to_drop = ['check','UNIQUE_ID','Plaintiff Last Name','Plaintiff First Name','Portfolio Id','Portfolio']
df = df.drop(columns = columns_to_drop)

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'], errors='coerce')
df['Last Collection Date'] = pd.to_datetime(df['Last Collection Date'], errors='coerce')
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_12404\3255311557.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Purchase Date'] = pd.to_datetime(df['Purchase Date'], errors='coerce')

# %%
# Remove non-numeric characters and convert to float, handling errors
df['Billing Amount'] = df['Billing Amount'].replace({'\$': '', ',': ''}, regex=True)
df['Total Capital Advanced'] = df['Total Capital Advanced'].replace({'\$': '', ',': ''}, regex=True)
df['$_Collection'] = df['$_Collection'].replace({'\$': '', ',': ''}, regex=True)

# Use pd.to_numeric to convert to float, coercing errors to NaN
df['Billing Amount'] = pd.to_numeric(df['Billing Amount'], errors='coerce')
df['Total Capital Advanced'] = pd.to_numeric(df['Total Capital Advanced'], errors='coerce')
df['$_Collection'] = pd.to_numeric(df['$_Collection'], errors='coerce')

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
with pd.option_context('display.float_format', '{:,.2f}'.format):
    print("\nDescription of the DataFrame:")
    print(df.describe())
# Out:
# Description of the DataFrame:
# 0      Billing Amount  Total Capital Advanced  $_Collection
# count      196,326.00              196,326.00    196,325.00
# mean         3,650.43                  952.31        140.51
# std        808,754.69              210,985.39     31,136.04
# min              0.00                    0.00       -223.78
# 25%            188.69                   41.11          0.00
# 50%            576.54                  102.03          0.00
# 75%          1,400.78                  388.30          0.00
# max    358,336,967.73           93,481,846.60 13,792,443.16

# %%
condition = (df['Lien Status'] == 'Settled') & (df['Case Status'] == 'Closed')

# Create two new DataFrames based on the condition
df_closed = df[condition]
df_open = df[~condition]

# %%
df_open
# Out:
# 0      Purchase Date  Billing Amount  Total Capital Advanced  $_Collection  \
# 0         2021-03-22        24100.00                 7712.00          0.00
# 1         2021-03-22        14500.00                 4640.00          0.00
# 2         2021-03-22        19500.00                 6240.00          0.00
# 3         2021-03-22         4900.00                 1568.00          0.00
# 4         2021-03-22        29200.00                 9344.00          0.00
# ...              ...             ...                     ...           ...
# 196321    2022-12-30         1045.00                  344.85          0.00
# 196322    2022-12-30         1581.34                  521.84          0.00
# 196323    2022-12-30         1330.00                  438.90          0.00
# 196324    2022-12-30         1539.86                  508.15          0.00
# 196325           NaT    358336967.73             93481846.60   13792443.16
#
# 0      Last Collection Date Lien Status Case Status
# ...

# %%
df_closed
# Out:
# 0      Purchase Date  Billing Amount  Total Capital Advanced  $_Collection  \
# 20        2021-03-22        14600.00                 4672.00       6992.32
# 80        2021-03-30        24200.00                 7744.00      12109.41
# 122       2021-03-30         9800.00                 3136.00       5181.15
# 131       2021-03-30        14700.00                 4704.00       6918.60
# 141       2021-03-30         4900.00                 1568.00       2306.20
# ...              ...             ...                     ...           ...
# 196225    2022-12-30         1723.76                  568.84       1295.53
# 196232    2022-12-30         1613.76                  532.54       1213.66
# 196245    2022-12-30          950.00                  313.50        714.47
# 196257    2022-12-30         1723.76                  568.84       1296.39
# 196297    2022-12-30         1440.00                  475.20       1081.68
#
# 0      Last Collection Date Lien Status Case Status
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Closed cases vs Open Cases

# %%
# Create a count plot for 'Case Status'
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Case Status', palette='viridis')
plt.title('Count of Open and Closed Cases')
plt.xlabel('Case Status')
plt.ylabel('Count')
plt.show()

# %%
df_open['Log Billing Amount'] = np.log1p(df_open['Billing Amount'])

# Create a histogram plot for 'Billing Amount' for Open Cases
plt.figure(figsize=(10, 6))
sns.histplot(df_open['Log Billing Amount'].dropna(), bins=100, kde=True)
plt.title('Distribution of Log Billing Amount')
plt.xlabel('Log Billing Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_12404\2848220440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_open['Log Billing Amount'] = np.log1p(df_open['Billing Amount'])

# %%
df_closed['Log Billing Amount'] = np.log1p(df_closed['Billing Amount'])

# Create a histogram plot for 'Billing Amount' for Closed Cases
plt.figure(figsize=(6, 6))
sns.histplot(df_closed['Log Billing Amount'].dropna(), bins=10, kde=True)
plt.title('Distribution of Log Billing Amount')
plt.xlabel('Log Billing Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\rajan\AppData\Local\Temp\ipykernel_12404\2227597434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_closed['Log Billing Amount'] = np.log1p(df_closed['Billing Amount'])
